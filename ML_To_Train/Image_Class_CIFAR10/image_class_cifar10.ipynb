# %% [markdown]
# # IMAGE CLASSIFIACTION FOR CIFAR10

# %% [markdown]
# # 1. Importing all packages

# %%
import torch
import torch as nn
import torch.optim as optim

import torchvision

# %% [markdown]
# # 2. importing dataset

# %%
import torchvision.datasets as CIFAR10

train_data = CIFAR10(root="dataset/", train=True, download=True, transform=transform)
test_data = CIFAR10(root="dataset/", train=False, download=True, transform=transform)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import torchvision.datasets as CIFAR10
# ----> 3 train_data = CIFAR10(root="dataset/", train=True, download=True)
#       4 test_data = CIFAR10(root="dataset/", train=False, download=True)
#
# TypeError: 'module' object is not callable

# %%
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

# Define transformations for the training and testing data
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert images to PyTorch tensors
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize the images 
])
